# %% [markdown]
# ## Assignment :Choose language(s) & alphabet of your choice and perform lcat and lstar on it .

# %% [markdown]
# # Lcat Function
#
# Alphabets (Σ) = {a,b}

# %% [markdown]
# Language (L1) = string of length 2
#
#           L1 = {"aa","ab","ba","bb"}
#
# Language (L2) = string of length 3
#
#           L2 = {"aaa","aab","aba","baa","abb","bab","bba","bbb"}

# %% [markdown]
# Defining Concatenation Function

# %%
def lcat(L1,L2):

     return {x+y for x in L1 for y in L2}

# %% [markdown]
# Result lcat function  :

# %%
L1 = {"aa","ab","ba","bb"}
L2 = {"aaa","aab","aba","baa","abb","bab","bba","bbb"}
lcat(L1,L2)
# Out:
# {'aaaaa',
#  'aaaab',
#  'aaaba',
#  'aaabb',
#  'aabaa',
#  'aabab',
#  'aabba',
#  'aabbb',
#  'abaaa',
#  'abaab',
#  'ababa',
#  'ababb',
#  'abbaa',
#  'abbab',
#  'abbba',
#  'abbbb',
#  'baaaa',
#  'baaab',
#  'baaba',
#  'baabb',
#  'babaa',
#  'babab',
#  'babba',
#  'babbb',
#  'bbaaa',
#  'bbaab',
#  'bbaba',
#  'bbabb',
#  'bbbaa',
#  'bbbab',
#  'bbbba',
#  'bbbbb'}

# %% [markdown]
# ## lstar Function

# %% [markdown]
# Define lstar function

# %%
def lstar(L1,n):
    
    star=set()
    for k in range(n+1):
        if k == 0:
            star.add("")
        else:
            new =lcat(star,L1)
            star.update(new)
    return star

# %% [markdown]
# Result lstar function

# %%
lstar(L1,2)
# Out:
# {'',
#  'aa',
#  'aaaa',
#  'aaab',
#  'aaba',
#  'aabb',
#  'ab',
#  'abaa',
#  'abab',
#  'abba',
#  'abbb',
#  'ba',
#  'baaa',
#  'baab',
#  'baba',
#  'babb',
#  'bb',
#  'bbaa',
#  'bbab',
#  'bbba',
#  'bbbb'}
